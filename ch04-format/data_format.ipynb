# %% [markdown]
# # Data Format Context

# %% [markdown]
# ## Image format

# %%
import matplotlib.pyplot as plt
import cv2 # mod
import numpy as np
from skimage import transform # mod

# %%
single_image = cv2.imread("data/000000000.jpg")

# %%
plt.imshow(single_image)
plt.show()

# %%
type(single_image)
# Out:
# numpy.ndarray

# %%
single_image.shape
# Out:
# (800, 1920, 3)

# %%
single_image = cv2.resize(single_image,(150, 150))

# %%
single_image.shape
# Out:
# (150, 150, 3)

# %%
plt.imshow(single_image)
plt.show()

# %%
gray_image = cv2.cvtColor(single_image, cv2.COLOR_RGB2GRAY)

# %%
gray_image.shape
# Out:
# (150, 150)

# %%
flipped_image = np.fliplr(gray_image)

# %%
plt.imshow(flipped_image)
plt.show()

# %%
rotated_image = transform.rotate(single_image, angle=45)

# %%
plt.imshow(rotated_image)
plt.show()

# %% [markdown]
# ## Text format

# %%
import pandas as pd
import nltk
import spacy

# %%
reviews = pd.read_json("data/Digital_Music_5.json", lines=True)

# %%
example_review = reviews["reviewText"].sample()

# %%
example_review = str(example_review)
example_review
# Out:
# '58736    Teen Dream is full of lush melodies suspended ...\nName: reviewText, dtype: object'

# %%
type(example_review)
# Out:
# str

# %%
sentences = nltk.sent_tokenize(example_review, "english")
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 sentences = nltk.sent_tokenize(example_review, "english")
#
# File c:\Users\JV\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\tokenize\__init__.py:106, in sent_tokenize(text, language)
#      96 def sent_tokenize(text, language="english"):
#      97     """
#      98     Return a sentence-tokenized copy of *text*,
#      99     using NLTK's recommended sentence tokenizer
#    (...)
#     104     :param language: the model name in the Punkt corpus
#     105     """
# --> 106     tokenizer = load(f"tokenizers/punkt/{language}.pickle")
#     107     return tokenizer.tokenize(text)
#
# File c:\Users\JV\AppData\Local\Programs\Python\Python311\Lib\site-packages\nltk\data.py:750, in load(resource_url, format, cache, verbose, logic_parser, fstruct_reader, encoding)
# ...

# %%
sentences
# Out:
# ['2664    When I first bought this Tupac album in 1996 I...\nName: reviewText, dtype: object']

# %%
words = nltk.word_tokenize(sentences[0])

# %%
english_stop_words = set(nltk.corpus.stopwords.words("english"))
cleaned_words = [word for word in words if word not in english_stop_words]
cleaned_words
# Out:
# ['2664',
#  'When',
#  'I',
#  'first',
#  'bought',
#  'Tupac',
#  'album',
#  '1996',
#  'I',
#  '...',
#  'Name',
#  ':',
#  'reviewText',
#  ',',
#  'dtype',
#  ':',
#  'object']

# %% [markdown]
# Here you'll need to download the model: `python -m spacy download en_core_web_sm`

# %%
nlp = spacy.load("en_core_web_sm")

# %%
doc = nlp(example_review)

# %%
type(doc)
# Out:
# spacy.tokens.doc.Doc

# %%
for token in doc:
    print(token.text, token.pos_)
# Out:
# 2664 NUM
#     SPACE
# When ADV
# I PRON
# first ADV
# bought VERB
# this DET
# Tupac PROPN
# album NOUN
# in ADP
# 1996 NUM
# I PRON
# ... PUNCT
#
#  SPACE
# Name NOUN
# : PUNCT
# reviewText VERB
# , PUNCT
# dtype VERB
# : PUNCT
# object NOUN
